# %% [markdown]
# ## EXERCICE SUR LES SERIES TEMPORELLES

# %%
import pandas as pd
import matplotlib.pyplot as plot
import numpy as num

# %%
data=pd.read_csv("./jeu_de_donnée/jeu_data1.csv")

# %%
data.head(7)
# Out:
#        Period       Revenue  Sales_quantity  Average_cost  \
# 0  01.01.2015  1.601007e+07         12729.0   1257.763541
# 1  01.02.2015  1.580759e+07         11636.0   1358.507000
# 2  01.03.2015  2.204715e+07         15922.0   1384.697024
# 3  01.04.2015  1.881458e+07         15227.0   1235.606705
# 4  01.05.2015  1.402148e+07          8620.0   1626.621765
# 5  01.06.2015  1.678393e+07         13160.0   1275.374508
# 6  01.07.2015  1.916189e+07         17254.0   1110.576805
#
#    The_average_annual_payroll_of_the_region
# 0                                30024676.0
# 1                                30024676.0
# 2                                30024676.0
# 3                                30024676.0
# 4                                30024676.0
# 5                                30024676.0
# 6                                30024676.0

# %% [markdown]
# ## valeur statisque

# %%
data["Sales_quantity"].describe()
# Out:
# count       64.000000
# mean     19197.375000
# std       6591.287257
# min       8314.000000
# 25%      15065.500000
# 50%      18368.000000
# 75%      22856.250000
# max      38069.000000
# Name: Sales_quantity, dtype: float64

# %%
moyenne=num.mean(data["Sales_quantity"])
print('moyenne', moyenne)
variance=num.std(data["Sales_quantity"])**2
print('variance',variance)
ecart_type=num.std(data["Sales_quantity"])
print('ecart-type', ecart_type)
# Out:
# moyenne 19197.375
# variance 42766238.51562499
# ecart-type 6539.5900877367685

# %% [markdown]
# ## Representation de la serie temporelle

# %%
data.dropna(inplace=True)
#suppression des valeurs manquantes

# %%
plot.figure(figsize=[18,7])
plot.plot(data["Period"],data["Sales_quantity"])
plot.xlim(0,64)
plot.xlabel("periodes")
plot.ylabel("quantité")
# Out:
# Text(0, 0.5, 'quantité')

# %% [markdown]
# ## Différents nuages de point

# %%
#N=1: (0-62)(1,63)
#sur les revenues

# %%
plot.figure(figsize=[25,18])
for N in range(1,9):
    plot.subplot(2,4,N)
    debut=0
    fin=64
    plot.title(f"N={N}")
    plot.xlabel("Xt")
    plot.ylabel(f"xt+{N}")
    plot.scatter(data["Sales_quantity"][debut:fin-N],data["Sales_quantity"][debut+N:fin])

# %% [markdown]
# ## Représenter la courbe des auto-corrélations ρ̂n (k) avec
# ## k = 1...50 (50 valeurs de k)

# %%
moy=num.mean(data["Sales_quantity"])

# %%
def auto_cov(data,k,moy):
    debut=0
    fin=len(data)
    xt=data[debut:fin-k]
    xt_k=data[debut+k:fin]
    cov=0
    for i in range(0,fin-k):
        cov=cov+(xt[i]-moy)*(xt_k[i]-moy)
        #calcul de L’auto-covariance empirique
    return (cov/(fin-k))

# %%
def auto_corr(data,k,moy):
    cov_0=auto_cov(data,0,moy)
    cov_k=auto_cov(data,k,moy)
    return (cov_k/cov_0)

# %%
correlation_k=[]
d=list(data["Sales_quantity"])
for cov in range (1,51):
    res=auto_corr(d,cov,moy)
    correlation_k.append(res)

# %%
views=[i for i in range(1,51)]
plot.bar(views,correlation_k)
# Out:
# <BarContainer object of 50 artists>
